# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
ngc3034 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc3034_mips24_image_v5-0.fits'
ngc3031 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc3031_mips24_image_v5-0.fits'
ngc4254 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc4254_mips24_image_v5-0.fits'
ngc4594 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc4594_mips24_image_v5-0.fits'
ngc4826 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc4826_mips24_image_v5-0.fits'
ngc5055 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc5055_mips24_image_v5-0.fits'
ngc5195 = '/Users/valerie/Projet exp L3/Calcul_SFR/24 microns - MIPS/ngc5195_mips24_image_v5-0.fits'

# %%
hdu3034 = fits.open(ngc3034)
hdu3031 = fits.open(ngc3031)
hdu4254 = fits.open(ngc4254)
hdu4594 = fits.open(ngc4594)
hdu4826 = fits.open(ngc4826)
hdu5055 = fits.open(ngc5055)
hdu5195 = fits.open(ngc5195)

# %%
galaxies = np.array([hdu3034,hdu3031,hdu4254,hdu4594,hdu4826, hdu5055, hdu5195])
im_galaxies = [h[0] for h in galaxies]
im_data = [i.data for i in im_galaxies]

# %%
images = galaxies  

names = ["NGC3034", "NGC3031", "NGC4254", "NGC4594", "NGC4826", "NGC5055", "NGC5195"]
vmax_list = [20, 10,10, 20, 5, 10, 20]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i, (img, name) in enumerate(zip(images, names)):
    data = img[0].data
    im = axes[i].imshow(data, vmax =vmax_list[i], cmap="plasma")
    axes[i].set_title(f"{names[i]}, 24 µm")
    axes[i].axis("off")
    fig.colorbar(im, ax=axes[i], fraction=0.046, pad=0.04)

# on désactive le subplot vide (8e case)
axes[-1].axis("off")

plt.tight_layout()
plt.show()

# %%
xminf = [1000,500,750,750,250,250,600]
xmaxf = [1500,1500,1000,1400,700,1000,800]
yminf = [300,1900,500,400,1900,1900,1000]
ymaxf = [500,2200,1000,800,2200,2200,1750]

xming = [650, 1050, 600, 670,550, 450,990]
xmaxg = [1200,1550, 800, 960,700, 720, 1030]
yming = [900,800, 1000, 1350,1130, 1050,1510]
ymaxg = [1500,1600, 1200, 1390,1200,1270,1550]

# %%
names = ["NGC 3034 / M82", "NGC 3031", "NGC 4254", "NGC 4594", "NGC 4826", "NGC 5055", "NGC 5195"]

# NGC 3034 / M82
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[0], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[0], yminf[0]), width=xmaxf[0]-xminf[0], height=ymaxf[0]-yminf[0], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[0], yming[0]), width=xmaxg[0]-xming[0], height=ymaxg[0]-yming[0], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[0]}, 24 µm")
plt.tight_layout()
plt.show()

# NGC 3031
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[1], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[1], yminf[1]), width=xmaxf[1]-xminf[1], height=ymaxf[1]-yminf[1], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[1], yming[1]), width=xmaxg[1]-xming[1], height=ymaxg[1]-yming[1], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[1]}, 24 µm")
plt.tight_layout()
plt.show()

# NGC 4254
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[2], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[2], yminf[2]), width=xmaxf[2]-xminf[2], height=ymaxf[2]-yminf[2], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[2], yming[2]), width=xmaxg[2]-xming[2], height=ymaxg[2]-yming[2], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[2]}, 24 µm")
plt.tight_layout()
plt.show()

# NGC 4594
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[3], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[3], yminf[3]), width=xmaxf[3]-xminf[3], height=ymaxf[3]-yminf[3], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[3], yming[3]), width=xmaxg[3]-xming[3], height=ymaxg[3]-yming[3], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[3]}, 24 µm")
plt.ylim(1000,2000)
plt.tight_layout()
plt.show()

# NGC 4826
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[4], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[4], yminf[4]), width=xmaxf[4]-xminf[4], height=ymaxf[4]-yminf[4], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[4], yming[4]), width=xmaxg[4]-xming[4], height=ymaxg[4]-yming[4], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[4]}, 24 µm")
plt.ylim(500,1500)
plt.tight_layout()
plt.show()

# NGC 5055
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[5], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[5], yminf[5]), width=xmaxf[5]-xminf[5], height=ymaxf[5]-yminf[5], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[5], yming[5]), width=xmaxg[5]-xming[5], height=ymaxg[5]-yming[5], linewidth=3, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[5]}, 24 µm")
plt.tight_layout()
plt.show()

# NGC 5195
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(im_data[6], vmax=50, cmap="flag", origin="upper")
#ax.add_patch(Rectangle((xminf[6], yminf[6]), width=xmaxf[6]-xminf[6], height=ymaxf[6]-yminf[6], linewidth=3, edgecolor='lime', facecolor='none', label='fond'))
ax.add_patch(Rectangle((xming[6], yming[6]), width=xmaxg[6]-xming[6], height=ymaxg[6]-yming[6], linewidth=1, edgecolor='yellow', facecolor='none', label="zone d'étude"))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
ax.set_title(f"{names[6]}, 24 µm")
plt.tight_layout()
plt.show()
